# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
CoilData = pd.read_csv("./DATA arcelormittalgent/CoilData.csv")

# %%
CoilData.head(70)
# Out:
#       coil  furnace Number analyse  Hardness_1  Hardness_2   Width  \
# 0   396378               1   K371        10003         101  1302.1
# 1   396376               3   K371        10123         101  1282.3
# 2   396377               4   K321        10040         102  1297.4
# 3   396379               3   K371        10243         102  1295.2
# 4   396380               4   K321        10012         100  1293.3
# ..     ...             ...     ...         ...         ...     ...
# 65  396442               3   K371        10202         102  1478.5
# 66  396443               1   K371        10236         102  1477.5
# 67  396444               4   K131        10116         102  1481.2
# 68  396445               3   K131        10059         100  1425.8
# 69  396447               4   T231        10479          91  1451.3
#
#     Temperature before finishing mill  Temperature after finishing mill  \
# 0                                1147                               921
# ...

# %%
CoilData.columns
# Out:
# Index(['coil', 'furnace Number', 'analyse', 'Hardness_1', 'Hardness_2',
#        'Width', 'Temperature before finishing mill',
#        'Temperature after finishing mill', 'Thickness', 'Thickness profile',
#        'c', 'mn', 'si', 'nb', 'p', 's', 'al', 'ma', 'b', 'n', 'ti', 'cr', 'va',
#        'mo'],
#       dtype='object')

# %%
CoilData.shape
# Out:
# (57094, 24)

# %%
CoilData.describe()
# Out:
#                 coil  furnace Number    Hardness_1    Hardness_2  \
# count   57094.000000    57094.000000  57094.000000  57094.000000
# mean   421911.707255        2.362157  11164.320349    110.903072
# std    137589.898062        1.280530   1346.841817     16.738803
# min     10001.000000        1.000000      0.000000      0.000000
# 25%    420475.250000        1.000000  10116.000000     99.000000
# 50%    454999.500000        3.000000  10504.000000    104.000000
# 75%    492857.750000        4.000000  12147.000000    123.000000
# max    533505.000000        4.000000  17362.000000    168.000000
#
#               Width  Temperature before finishing mill  \
# count  57094.000000                       57094.000000
# mean    1260.063262                        1165.911076
# std      290.336376                          78.302204
# min        0.000000                           0.000000
# 25%     1093.025000                        1155.000000
# ...

# %%
CoilData = CoilData.replace('^\*+$', np.NaN, regex=True)
CoilData.head(70)
# Out:
#       coil  furnace Number analyse  Hardness_1  Hardness_2   Width  \
# 0   396378               1   K371        10003         101  1302.1
# 1   396376               3   K371        10123         101  1282.3
# 2   396377               4   K321        10040         102  1297.4
# 3   396379               3   K371        10243         102  1295.2
# 4   396380               4   K321        10012         100  1293.3
# ..     ...             ...     ...         ...         ...     ...
# 65  396442               3   K371        10202         102  1478.5
# 66  396443               1   K371        10236         102  1477.5
# 67  396444               4   K131        10116         102  1481.2
# 68  396445               3   K131        10059         100  1425.8
# 69  396447               4   T231        10479          91  1451.3
#
#     Temperature before finishing mill  Temperature after finishing mill  \
# 0                                1147                               921
# ...

# %%
print(CoilData.isnull().sum())
# Out:
# coil                                   0
# furnace Number                         0
# analyse                                0
# Hardness_1                             0
# Hardness_2                             0
# Width                                  0
# Temperature before finishing mill      0
# Temperature after finishing mill       0
# Thickness                              0
# Thickness profile                    511
# c                                      0
# mn                                     0
# si                                     0
# nb                                     0
# p                                      0
# s                                      0
# al                                     0
# ma                                     0
# b                                      0
# n                                      0
# ti                                     0
# cr                                     0
# va                                     0
# ...

# %%
CoilDatanew= CoilData.dropna()
CoilDatanew.head(70)
# Out:
#       coil  furnace Number analyse  Hardness_1  Hardness_2   Width  \
# 0   396378               1   K371        10003         101  1302.1
# 1   396376               3   K371        10123         101  1282.3
# 2   396377               4   K321        10040         102  1297.4
# 3   396379               3   K371        10243         102  1295.2
# 4   396380               4   K321        10012         100  1293.3
# ..     ...             ...     ...         ...         ...     ...
# 65  396442               3   K371        10202         102  1478.5
# 66  396443               1   K371        10236         102  1477.5
# 78  396456               4   T211        10385          91  1361.3
# 79  396457               3   K321         9844          98  1412.8
# 80  396458               1   KB38        11168         112  1390.8
#
#     Temperature before finishing mill  Temperature after finishing mill  \
# 0                                1147                               921
# ...

# %%
CoilDatanew = CoilDatanew.reset_index(drop=True)
CoilDatanew.head(70)
# Out:
#       coil  furnace Number analyse  Hardness_1  Hardness_2   Width  \
# 0   396378               1   K371        10003         101  1302.1
# 1   396376               3   K371        10123         101  1282.3
# 2   396377               4   K321        10040         102  1297.4
# 3   396379               3   K371        10243         102  1295.2
# 4   396380               4   K321        10012         100  1293.3
# ..     ...             ...     ...         ...         ...     ...
# 65  396442               3   K371        10202         102  1478.5
# 66  396443               1   K371        10236         102  1477.5
# 67  396456               4   T211        10385          91  1361.3
# 68  396457               3   K321         9844          98  1412.8
# 69  396458               1   KB38        11168         112  1390.8
#
#     Temperature before finishing mill  Temperature after finishing mill  \
# 0                                1147                               921
# ...
